# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tautira
# Processing Record 2 of Set 1 | umba
# Processing Record 3 of Set 1 | quatre cocos
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | remedios
# Processing Record 6 of Set 1 | sibiti
# Processing Record 7 of Set 1 | kieta
# Processing Record 8 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 9 of Set 1 | norrtalje
# Processing Record 10 of Set 1 | vila franca do campo
# Processing Record 11 of Set 1 | penne
# Processing Record 12 of Set 1 | stornoway
# Processing Record 13 of Set 1 | itarema
# Processing Record 14 of Set 1 | cilegon
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | pozo colorado
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | kamaishi
# Processing Record 27 of Set 1 | tolaga bay
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | priiskovyy
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | ponta delgada
# Processing Record 32 of Set 1 | linqiong
# Processing Record 33 of Set 1 | kushiro
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | atar
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | te karaka
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | batouri
# Processing Record 46 of Set 1 | port augusta
# Processing Record 47 of Set 1 | chimoio
# Processing Record 48 of Set 1 | guadalupe y calvo
# Processing Record 49 of Set 1 | honningsvag
# Processing Record 50 of Set 1 | sola
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | tombouctou
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | muhos
# Processing Record 7 of Set 2 | ridgecrest
# Processing Record 8 of Set 2 | jilin
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | bud
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | beloha
# Processing Record 15 of Set 2 | mehamn
# Processing Record 16 of Set 2 | biak
# Processing Record 17 of Set 2 | bolshiye uki
# City not found. Skipping...
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | calderitas
# Processing Record 20 of Set 2 | aksarka
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | fort nelson
# Processing Record 23 of Set 2 | paramonga
# Processing Record 24 of Set 2 | kortkeros
# Processing Record 25 of Set 2 | oistins
# Processing Record 26 of Set 2 | saint-pierre
# Processing Record 27 of Set 2 | malakal
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | morwell
# Processing Record 31 of Set 2 | kumano
# Processing Record 32 of Set 2 | rock sound
# Processing Record 33 of Set 2 | vila velha
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | poum
# Processing Record 38 of Set 2 | solnechnyy
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | ballina
# Processing Record 41 of Set 2 | san andres
# Processing Record 42 of Set 2 | vardo
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | aswan
# Processing Record 45 of Set 2 | bama
# Processing Record 46 of Set 2 | cervo
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | tuatapere
# Processing Record 49 of Set 2 | beira
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | zhangjiakou
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | port hedland
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | okmulgee
# Processing Record 16 of Set 3 | itacarambi
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | hinton
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | chengde
# Processing Record 21 of Set 3 | dabhol
# Processing Record 22 of Set 3 | suez
# Processing Record 23 of Set 3 | kasongo-lunda
# Processing Record 24 of Set 3 | anloga
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 3 | laguna
# Processing Record 28 of Set 3 | muroto
# Processing Record 29 of Set 3 | thinadhoo
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | tuscaloosa
# Processing Record 35 of Set 3 | cangzhou
# Processing Record 36 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 3 | valdosta
# Processing Record 38 of Set 3 | castro marim
# Processing Record 39 of Set 3 | raudeberg
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | hervey bay
# Processing Record 44 of Set 3 | zyryanka
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | puerto madryn
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | guerrero negro
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | klaksvik
# Processing Record 1 of Set 4 | dunedin
# Processing Record 2 of Set 4 | kayes
# Processing Record 3 of Set 4 | domoni
# Processing Record 4 of Set 4 | victoria point
# Processing Record 5 of Set 4 | ixtapa
# Processing Record 6 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 4 | muravlenko
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 10 of Set 4 | san quintin
# Processing Record 11 of Set 4 | rafai
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | vestmannaeyjar
# Processing Record 14 of Set 4 | chapleau
# Processing Record 15 of Set 4 | giyon
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 19 of Set 4 | viesca
# Processing Record 20 of Set 4 | port macquarie
# Processing Record 21 of Set 4 | sydney
# Processing Record 22 of Set 4 | rapar
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | novi pazar
# Processing Record 26 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 4 | puerto ayora
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | medicine hat
# Processing Record 31 of Set 4 | matara
# Processing Record 32 of Set 4 | tessalit
# Processing Record 33 of Set 4 | taikang
# Processing Record 34 of Set 4 | souillac
# Processing Record 35 of Set 4 | barrow
# Processing Record 36 of Set 4 | sabang
# Processing Record 37 of Set 4 | nome
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | morondava
# Processing Record 40 of Set 4 | vostok
# Processing Record 41 of Set 4 | mujiayingzi
# Processing Record 42 of Set 4 | cairns
# Processing Record 43 of Set 4 | kichera
# Processing Record 44 of Set 4 | aldan
# Processing Record 45 of Set 4 | srikakulam
# Processing Record 46 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 47 of Set 4 | snyder
# Processing Record 48 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 4 | torbay
# Processing Record 50 of Set 4 | komsomolskiy
# Processing Record 1 of Set 5 | curuca
# Processing Record 2 of Set 5 | alice springs
# Processing Record 3 of Set 5 | kalmunai
# Processing Record 4 of Set 5 | asyut
# Processing Record 5 of Set 5 | beisfjord
# Processing Record 6 of Set 5 | charters towers
# Processing Record 7 of Set 5 | hermanus
# Processing Record 8 of Set 5 | jinxiang
# Processing Record 9 of Set 5 | kununurra
# Processing Record 10 of Set 5 | ust-kuyga
# Processing Record 11 of Set 5 | san pedro
# Processing Record 12 of Set 5 | shache
# Processing Record 13 of Set 5 | puerto baquerizo moreno
# Processing Record 14 of Set 5 | inuvik
# Processing Record 15 of Set 5 | belousovka
# Processing Record 16 of Set 5 | porto santo
# Processing Record 17 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 5 | red wing
# Processing Record 19 of Set 5 | labuan
# Processing Record 20 of Set 5 | odesskoye
# Processing Record 21 of Set 5 | bad segeberg
# Processing Record 22 of Set 5 | jieshi
# Processing Record 23 of Set 5 | nadvoitsy
# Processing Record 24 of Set 5 | carutapera
# Processing Record 25 of Set 5 | jackson
# Processing Record 26 of Set 5 | bambous virieux
# Processing Record 27 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 5 | deputatskiy
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | prainha
# Processing Record 32 of Set 5 | pytalovo
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | perth
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | lokosovo
# Processing Record 38 of Set 5 | zhigansk
# Processing Record 39 of Set 5 | srednebelaya
# Processing Record 40 of Set 5 | ilulissat
# Processing Record 41 of Set 5 | skibbereen
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | usinsk
# Processing Record 44 of Set 5 | rawson
# Processing Record 45 of Set 5 | fairview
# Processing Record 46 of Set 5 | muros
# Processing Record 47 of Set 5 | ukiah
# Processing Record 48 of Set 5 | yei
# Processing Record 49 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 5 | klyuchi
# Processing Record 1 of Set 6 | akyab
# Processing Record 2 of Set 6 | rio cuarto
# Processing Record 3 of Set 6 | mumford
# Processing Record 4 of Set 6 | sorland
# Processing Record 5 of Set 6 | moen
# Processing Record 6 of Set 6 | synya
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | longyearbyen
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | byumba
# Processing Record 11 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 6 | georgetown
# Processing Record 13 of Set 6 | cartagena
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 16 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 6 | skelleftea
# Processing Record 18 of Set 6 | hambantota
# Processing Record 19 of Set 6 | codrington
# Processing Record 20 of Set 6 | kodinsk
# Processing Record 21 of Set 6 | kudahuvadhoo
# Processing Record 22 of Set 6 | mildura
# Processing Record 23 of Set 6 | chumikan
# Processing Record 24 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 6 | bilibino
# Processing Record 26 of Set 6 | faya
# Processing Record 27 of Set 6 | phangnga
# Processing Record 28 of Set 6 | alta floresta
# Processing Record 29 of Set 6 | kavaratti
# Processing Record 30 of Set 6 | baruun-urt
# Processing Record 31 of Set 6 | teguise
# Processing Record 32 of Set 6 | kyabram
# Processing Record 33 of Set 6 | batsfjord
# Processing Record 34 of Set 6 | nikolskoye
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | yellowknife
# Processing Record 37 of Set 6 | belaya gora
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | morros
# Processing Record 40 of Set 6 | catamarca
# Processing Record 41 of Set 6 | keffi
# Processing Record 42 of Set 6 | gorontalo
# Processing Record 43 of Set 6 | hovd
# Processing Record 44 of Set 6 | dhanera
# Processing Record 45 of Set 6 | te anau
# Processing Record 46 of Set 6 | saint-philippe
# Processing Record 47 of Set 6 | chingirlau
# Processing Record 48 of Set 6 | santa lucia
# Processing Record 49 of Set 6 | broome
# Processing Record 50 of Set 6 | college
# Processing Record 1 of Set 7 | atmakur
# Processing Record 2 of Set 7 | cayenne
# Processing Record 3 of Set 7 | lasa
# Processing Record 4 of Set 7 | pavlodar
# Processing Record 5 of Set 7 | bacungan
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | roura
# Processing Record 8 of Set 7 | zhuanghe
# Processing Record 9 of Set 7 | lebu
# Processing Record 10 of Set 7 | abalak
# Processing Record 11 of Set 7 | caravelas
# Processing Record 12 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 7 | puerto escondido
# Processing Record 14 of Set 7 | turmero
# Processing Record 15 of Set 7 | basco
# Processing Record 16 of Set 7 | samdari
# Processing Record 17 of Set 7 | mandalgovi
# Processing Record 18 of Set 7 | mecca
# Processing Record 19 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 7 | manjacaze
# Processing Record 21 of Set 7 | khanpur
# Processing Record 22 of Set 7 | hami
# Processing Record 23 of Set 7 | almaznyy
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | mora
# Processing Record 26 of Set 7 | touros
# Processing Record 27 of Set 7 | susaki
# Processing Record 28 of Set 7 | srednekolymsk
# Processing Record 29 of Set 7 | rockland
# Processing Record 30 of Set 7 | kaeo
# Processing Record 31 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 7 | kupang
# Processing Record 33 of Set 7 | lazaro cardenas
# Processing Record 34 of Set 7 | longview
# Processing Record 35 of Set 7 | rio grande
# Processing Record 36 of Set 7 | saint anthony
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | toccoa
# Processing Record 39 of Set 7 | kinel-cherkassy
# Processing Record 40 of Set 7 | yenagoa
# Processing Record 41 of Set 7 | wilmington
# Processing Record 42 of Set 7 | airai
# Processing Record 43 of Set 7 | katsuura
# Processing Record 44 of Set 7 | port lincoln
# Processing Record 45 of Set 7 | sinnamary
# Processing Record 46 of Set 7 | ayorou
# Processing Record 47 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 7 | timra
# Processing Record 49 of Set 7 | dikson
# Processing Record 50 of Set 7 | fernie
# Processing Record 1 of Set 8 | saint george
# Processing Record 2 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 3 of Set 8 | bereda
# Processing Record 4 of Set 8 | pangnirtung
# Processing Record 5 of Set 8 | ushibuka
# Processing Record 6 of Set 8 | rocha
# Processing Record 7 of Set 8 | ruteng
# Processing Record 8 of Set 8 | xiamen
# Processing Record 9 of Set 8 | whitehorse
# Processing Record 10 of Set 8 | roma
# Processing Record 11 of Set 8 | opuwo
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | maragogi
# Processing Record 14 of Set 8 | blagoyevo
# Processing Record 15 of Set 8 | bubaque
# Processing Record 16 of Set 8 | sept-iles
# Processing Record 17 of Set 8 | junction city
# Processing Record 18 of Set 8 | aanekoski
# Processing Record 19 of Set 8 | bouar
# Processing Record 20 of Set 8 | algarrobo
# Processing Record 21 of Set 8 | tucuman
# Processing Record 22 of Set 8 | west monroe
# Processing Record 23 of Set 8 | gudalur
# Processing Record 24 of Set 8 | concordia
# Processing Record 25 of Set 8 | norsup
# Processing Record 26 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 8 | klamath falls
# Processing Record 28 of Set 8 | ahipara
# Processing Record 29 of Set 8 | walvis bay
# Processing Record 30 of Set 8 | kearney
# Processing Record 31 of Set 8 | maputo
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | marawi
# Processing Record 34 of Set 8 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 35 of Set 8 | ginda
# Processing Record 36 of Set 8 | bayangol
# Processing Record 37 of Set 8 | huarmey
# Processing Record 38 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 8 | waunakee
# Processing Record 40 of Set 8 | chikoy
# City not found. Skipping...
# Processing Record 41 of Set 8 | balaipungut
# Processing Record 42 of Set 8 | nongan
# Processing Record 43 of Set 8 | ji-parana
# City not found. Skipping...
# Processing Record 44 of Set 8 | tezu
# Processing Record 45 of Set 8 | bull savanna
# Processing Record 46 of Set 8 | nara
# Processing Record 47 of Set 8 | la union
# Processing Record 48 of Set 8 | kaseda
# Processing Record 49 of Set 8 | coos bay
# Processing Record 50 of Set 8 | narsaq
# Processing Record 1 of Set 9 | tukrah
# Processing Record 2 of Set 9 | nishihara
# Processing Record 3 of Set 9 | amapa
# Processing Record 4 of Set 9 | oranjemund
# Processing Record 5 of Set 9 | los llanos de aridane
# Processing Record 6 of Set 9 | alcaniz
# Processing Record 7 of Set 9 | semey
# Processing Record 8 of Set 9 | pandan
# Processing Record 9 of Set 9 | curup
# Processing Record 10 of Set 9 | dongsheng
# Processing Record 11 of Set 9 | batagay-alyta
# Processing Record 12 of Set 9 | nouadhibou
# Processing Record 13 of Set 9 | tateyama
# Processing Record 14 of Set 9 | minden
# Processing Record 15 of Set 9 | ciudad guayana
# Processing Record 16 of Set 9 | gornyy
# Processing Record 17 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 18 of Set 9 | gat
# Processing Record 19 of Set 9 | cuiluan
# Processing Record 20 of Set 9 | allanmyo
# City not found. Skipping...
# Processing Record 21 of Set 9 | virginia beach
# Processing Record 22 of Set 9 | husavik
# Processing Record 23 of Set 9 | quelimane
# Processing Record 24 of Set 9 | juazeiro do norte
# Processing Record 25 of Set 9 | sakakah
# Processing Record 26 of Set 9 | powell river
# Processing Record 27 of Set 9 | zinder
# Processing Record 28 of Set 9 | keflavik
# Processing Record 29 of Set 9 | fuyu
# Processing Record 30 of Set 9 | tecoanapa
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | lata
# Processing Record 33 of Set 9 | gardner
# Processing Record 34 of Set 9 | iquitos
# Processing Record 35 of Set 9 | port-gentil
# Processing Record 36 of Set 9 | mahajanga
# Processing Record 37 of Set 9 | namibe
# Processing Record 38 of Set 9 | gizo
# Processing Record 39 of Set 9 | los andes
# Processing Record 40 of Set 9 | awjilah
# Processing Record 41 of Set 9 | buba
# Processing Record 42 of Set 9 | waingapu
# Processing Record 43 of Set 9 | pochutla
# Processing Record 44 of Set 9 | aklavik
# Processing Record 45 of Set 9 | havre-saint-pierre
# Processing Record 46 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 9 | shubarshi
# Processing Record 49 of Set 9 | artyom
# Processing Record 50 of Set 9 | shubarkuduk
# Processing Record 1 of Set 10 | mount gambier
# Processing Record 2 of Set 10 | acajutla
# Processing Record 3 of Set 10 | victor harbor
# Processing Record 4 of Set 10 | thunder bay
# Processing Record 5 of Set 10 | ucluelet
# Processing Record 6 of Set 10 | laurel
# Processing Record 7 of Set 10 | kiunga
# Processing Record 8 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 10 | bulanash
# Processing Record 10 of Set 10 | east london
# Processing Record 11 of Set 10 | sao filipe
# Processing Record 12 of Set 10 | talaya
# Processing Record 13 of Set 10 | tangzhai
# Processing Record 14 of Set 10 | saint-francois
# Processing Record 15 of Set 10 | diego de almagro
# Processing Record 16 of Set 10 | kropotkin
# Processing Record 17 of Set 10 | lavrentiya
# Processing Record 18 of Set 10 | zdunska wola
# Processing Record 19 of Set 10 | praia da vitoria
# Processing Record 20 of Set 10 | panzhihua
# Processing Record 21 of Set 10 | abu dhabi
# Processing Record 22 of Set 10 | houma
# Processing Record 23 of Set 10 | oksfjord
# Processing Record 24 of Set 10 | asau
# Processing Record 25 of Set 10 | rostovka
# Processing Record 26 of Set 10 | karema
# Processing Record 27 of Set 10 | areka
# Processing Record 28 of Set 10 | salalah
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 10 | tulum
# Processing Record 32 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 10 | novo aripuana
# Processing Record 34 of Set 10 | sulangan
# Processing Record 35 of Set 10 | roald
# Processing Record 36 of Set 10 | kiama
# Processing Record 37 of Set 10 | george town
# Processing Record 38 of Set 10 | libertador general san martin
# Processing Record 39 of Set 10 | tura
# Processing Record 40 of Set 10 | de-kastri
# Processing Record 41 of Set 10 | alanya
# Processing Record 42 of Set 10 | portland
# Processing Record 43 of Set 10 | portneuf
# Processing Record 44 of Set 10 | sao joao nepomuceno
# Processing Record 45 of Set 10 | chernyshevskiy
# Processing Record 46 of Set 10 | bathsheba
# Processing Record 47 of Set 10 | hearst
# Processing Record 48 of Set 10 | champerico
# Processing Record 49 of Set 10 | camacupa
# Processing Record 50 of Set 10 | mkushi
# Processing Record 1 of Set 11 | nirasaki
# Processing Record 2 of Set 11 | korla
# Processing Record 3 of Set 11 | antalaha
# Processing Record 4 of Set 11 | mount isa
# Processing Record 5 of Set 11 | mizan teferi
# Processing Record 6 of Set 11 | kamenka
# Processing Record 7 of Set 11 | shimoda
# Processing Record 8 of Set 11 | alice town
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | gasa
# Processing Record 11 of Set 11 | taltal
# Processing Record 12 of Set 11 | verkhnevilyuysk
# Processing Record 13 of Set 11 | yiyang
# Processing Record 14 of Set 11 | la primavera
# Processing Record 15 of Set 11 | dandong
# Processing Record 16 of Set 11 | inongo
# Processing Record 17 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 18 of Set 11 | saint-felicien
# Processing Record 19 of Set 11 | lac-megantic
# Processing Record 20 of Set 11 | cabedelo
# Processing Record 21 of Set 11 | verkhniy avzyan
# Processing Record 22 of Set 11 | leo
# Processing Record 23 of Set 11 | kristiinankaupunki
# Processing Record 24 of Set 11 | amga
# Processing Record 25 of Set 11 | campana
# Processing Record 26 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 27 of Set 11 | kavieng
# Processing Record 28 of Set 11 | abu samrah
# Processing Record 29 of Set 11 | jerome
# Processing Record 30 of Set 11 | hay river
# Processing Record 31 of Set 11 | mitsamiouli
# Processing Record 32 of Set 11 | flinders
# Processing Record 33 of Set 11 | paraiso
# Processing Record 34 of Set 11 | mazagao
# Processing Record 35 of Set 11 | verkhnyaya inta
# Processing Record 36 of Set 11 | ambilobe
# Processing Record 37 of Set 11 | makasar
# Processing Record 38 of Set 11 | saskylakh
# Processing Record 39 of Set 11 | bonthe
# Processing Record 40 of Set 11 | jijiga
# Processing Record 41 of Set 11 | lusambo
# Processing Record 42 of Set 11 | berlevag
# Processing Record 43 of Set 11 | chinhoyi
# Processing Record 44 of Set 11 | mogadishu
# Processing Record 45 of Set 11 | mugur-aksy
# Processing Record 46 of Set 11 | providencia
# Processing Record 47 of Set 11 | wawa
# Processing Record 48 of Set 11 | netishyn
# Processing Record 49 of Set 11 | kashi
# Processing Record 50 of Set 11 | buala
# Processing Record 1 of Set 12 | uhlove
# Processing Record 2 of Set 12 | birao
# Processing Record 3 of Set 12 | zhigalovo
# Processing Record 4 of Set 12 | olafsvik
# Processing Record 5 of Set 12 | zemio
# Processing Record 6 of Set 12 | dzhebariki-khaya
# Processing Record 7 of Set 12 | kaabong
# Processing Record 8 of Set 12 | nizhniy odes
# Processing Record 9 of Set 12 | hofn
# Processing Record 10 of Set 12 | churapcha
# Processing Record 11 of Set 12 | talcahuano
# Processing Record 12 of Set 12 | poya
# Processing Record 13 of Set 12 | hasaki
# Processing Record 14 of Set 12 | olive branch
# Processing Record 15 of Set 12 | tomatlan
# Processing Record 16 of Set 12 | kakonko
# Processing Record 17 of Set 12 | shakhtinsk
# Processing Record 18 of Set 12 | harnosand
# Processing Record 19 of Set 12 | faanui
# Processing Record 20 of Set 12 | nalut
# Processing Record 21 of Set 12 | turukhansk
# Processing Record 22 of Set 12 | lincoln
# Processing Record 23 of Set 12 | katangli
# Processing Record 24 of Set 12 | guarapari
# Processing Record 25 of Set 12 | comodoro rivadavia
# Processing Record 26 of Set 12 | vilhena
# Processing Record 27 of Set 12 | egvekinot
# Processing Record 28 of Set 12 | coahuayana
# Processing Record 29 of Set 12 | careiro da varzea
# Processing Record 30 of Set 12 | villamontes
# Processing Record 31 of Set 12 | nenjiang
# Processing Record 32 of Set 12 | seoul
# Processing Record 33 of Set 12 | ouegoa
# Processing Record 34 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 35 of Set 12 | warmbad
# Processing Record 36 of Set 12 | krutikha
# Processing Record 37 of Set 12 | chapais
# Processing Record 38 of Set 12 | fortuna foothills
# Processing Record 39 of Set 12 | asfi
# Processing Record 40 of Set 12 | salyan
# Processing Record 41 of Set 12 | waipawa
# Processing Record 42 of Set 12 | westerland
# Processing Record 43 of Set 12 | dalinghe
# City not found. Skipping...
# Processing Record 44 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 46 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 47 of Set 12 | benito juarez
# Processing Record 48 of Set 12 | le port
# Processing Record 49 of Set 12 | isla mujeres
# Processing Record 50 of Set 12 | boden
# Processing Record 1 of Set 13 | derzhavinsk
# Processing Record 2 of Set 13 | tumarbong
# Processing Record 3 of Set 13 | hualmay
# Processing Record 4 of Set 13 | teluk nibung
# Processing Record 5 of Set 13 | moerai
# Processing Record 6 of Set 13 | petrozavodsk
# Processing Record 7 of Set 13 | qingdao
# Processing Record 8 of Set 13 | visby
# Processing Record 9 of Set 13 | tavares
# Processing Record 10 of Set 13 | mareeba
# Processing Record 11 of Set 13 | half moon bay
# Processing Record 12 of Set 13 | arrecife
# Processing Record 13 of Set 13 | ondangwa
# Processing Record 14 of Set 13 | la asuncion
# Processing Record 15 of Set 13 | yining
# Processing Record 16 of Set 13 | letlhakane
# Processing Record 17 of Set 13 | pimentel
# Processing Record 18 of Set 13 | north bend
# Processing Record 19 of Set 13 | la ronge
# Processing Record 20 of Set 13 | bardiyah
# Processing Record 21 of Set 13 | pingliang
# Processing Record 22 of Set 13 | lahat
# Processing Record 23 of Set 13 | port hardy
# Processing Record 24 of Set 13 | carauari
# Processing Record 25 of Set 13 | sioux lookout
# Processing Record 26 of Set 13 | gravdal
# Processing Record 27 of Set 13 | morehead
# Processing Record 28 of Set 13 | palakkad
# Processing Record 29 of Set 13 | coruripe
# Processing Record 30 of Set 13 | augusto correa
# Processing Record 31 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 13 | viedma
# Processing Record 33 of Set 13 | segou
# Processing Record 34 of Set 13 | tilichiki
# Processing Record 35 of Set 13 | buckeye
# Processing Record 36 of Set 13 | shingu
# Processing Record 37 of Set 13 | nyurba
# Processing Record 38 of Set 13 | port dover
# Processing Record 39 of Set 13 | ravar
# Processing Record 40 of Set 13 | santa fe
# Processing Record 41 of Set 13 | tobermory
# Processing Record 42 of Set 13 | leshukonskoye
# Processing Record 43 of Set 13 | tazovskiy
# Processing Record 44 of Set 13 | inhambane
# Processing Record 45 of Set 13 | reconquista
# Processing Record 46 of Set 13 | serenje
# Processing Record 47 of Set 13 | burica
# City not found. Skipping...
# Processing Record 48 of Set 13 | belmonte
# Processing Record 49 of Set 13 | barcelos
# Processing Record 50 of Set 13 | san juan
# Processing Record 1 of Set 14 | kulhudhuffushi
# Processing Record 2 of Set 14 | baykit
# Processing Record 3 of Set 14 | duz
# City not found. Skipping...
# Processing Record 4 of Set 14 | aulnoye-aymeries
# Processing Record 5 of Set 14 | araouane
# Processing Record 6 of Set 14 | xushan
# Processing Record 7 of Set 14 | rypin
# Processing Record 8 of Set 14 | pacific grove
# Processing Record 9 of Set 14 | encheng
# Processing Record 10 of Set 14 | puerto carreno
# Processing Record 11 of Set 14 | nizhniy baskunchak
# Processing Record 12 of Set 14 | newport
# Processing Record 13 of Set 14 | bechyne
# Processing Record 14 of Set 14 | manyana
# Processing Record 15 of Set 14 | gilgit
# Processing Record 16 of Set 14 | puerto asis
# Processing Record 17 of Set 14 | burnie
# Processing Record 18 of Set 14 | sechura
# Processing Record 19 of Set 14 | cancun
# Processing Record 20 of Set 14 | buin
# Processing Record 21 of Set 14 | miraflores
# Processing Record 22 of Set 14 | altagracia de orituco
# Processing Record 23 of Set 14 | sabha
# Processing Record 24 of Set 14 | aguas formosas
# Processing Record 25 of Set 14 | vanavara
# Processing Record 26 of Set 14 | poronaysk
# Processing Record 27 of Set 14 | santona
# Processing Record 28 of Set 14 | mikuni
# Processing Record 29 of Set 14 | la huacana
# Processing Record 30 of Set 14 | carballo
# Processing Record 31 of Set 14 | ugoofaaru
# Processing Record 32 of Set 14 | jiuquan
# Processing Record 33 of Set 14 | san javier
# Processing Record 34 of Set 14 | namatanai
# Processing Record 35 of Set 14 | west norriton
# Processing Record 36 of Set 14 | iralaya
# Processing Record 37 of Set 14 | high level
# Processing Record 38 of Set 14 | kloulklubed
# Processing Record 39 of Set 14 | ceres
# Processing Record 40 of Set 14 | nemuro
# Processing Record 41 of Set 14 | santa catarina
# Processing Record 42 of Set 14 | ban nahin
# Processing Record 43 of Set 14 | haapiti
# Processing Record 44 of Set 14 | lima
# Processing Record 45 of Set 14 | aventura
# Processing Record 46 of Set 14 | saint-joseph
# Processing Record 47 of Set 14 | mandan
# Processing Record 48 of Set 14 | kutum
# Processing Record 49 of Set 14 | canberra
# Processing Record 50 of Set 14 | jalu
# Processing Record 1 of Set 15 | altay
# Processing Record 2 of Set 15 | hailar
# Processing Record 3 of Set 15 | pokosnoye
# Processing Record 4 of Set 15 | manaure
# Processing Record 5 of Set 15 | sinjar
# Processing Record 6 of Set 15 | peniche
# Processing Record 7 of Set 15 | singkawang
# Processing Record 8 of Set 15 | anahuac
# Processing Record 9 of Set 15 | kahului
# Processing Record 10 of Set 15 | pilar
# Processing Record 11 of Set 15 | arroyo
# Processing Record 12 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 15 | middelburg
# Processing Record 14 of Set 15 | am timan
# Processing Record 15 of Set 15 | fairbanks
# Processing Record 16 of Set 15 | porto novo
# Processing Record 17 of Set 15 | oussouye
# Processing Record 18 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 15 | huancavelica
# Processing Record 20 of Set 15 | cabo san lucas
# Processing Record 21 of Set 15 | ketchikan
# Processing Record 22 of Set 15 | chauk
# Processing Record 23 of Set 15 | qui nhon
# Processing Record 24 of Set 15 | tulun
# Processing Record 25 of Set 15 | filadelfia
# Processing Record 26 of Set 15 | tutoia
# Processing Record 27 of Set 15 | zabol
# Processing Record 28 of Set 15 | damghan
# Processing Record 29 of Set 15 | beringovskiy
# Processing Record 30 of Set 15 | camacha
# Processing Record 31 of Set 15 | staryy nadym
# Processing Record 32 of Set 15 | pacatuba
# Processing Record 33 of Set 15 | matagami
# Processing Record 34 of Set 15 | murray bridge
# Processing Record 35 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 15 | machali
# Processing Record 37 of Set 15 | mountain home
# Processing Record 38 of Set 15 | dano
# Processing Record 39 of Set 15 | cardston
# Processing Record 40 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 15 | umm lajj
# Processing Record 42 of Set 15 | otacilio costa
# Processing Record 43 of Set 15 | upata
# Processing Record 44 of Set 15 | skjervoy
# Processing Record 45 of Set 15 | omsukchan
# Processing Record 46 of Set 15 | boke
# Processing Record 47 of Set 15 | camopi
# Processing Record 48 of Set 15 | guilin
# Processing Record 49 of Set 15 | brownsville
# Processing Record 50 of Set 15 | nantucket
# Processing Record 1 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 16 | panguipulli
# Processing Record 3 of Set 16 | carlos barbosa
# Processing Record 4 of Set 16 | labuhan
# Processing Record 5 of Set 16 | boa vista
# Processing Record 6 of Set 16 | hokitika
# Processing Record 7 of Set 16 | aberdeen
# Processing Record 8 of Set 16 | chota
# Processing Record 9 of Set 16 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 16 | san policarpo
# Processing Record 11 of Set 16 | padang
# Processing Record 12 of Set 16 | elko
# Processing Record 13 of Set 16 | kysyl-syr
# Processing Record 14 of Set 16 | linqu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tautira -17.7333 -149.1500     78.82        79         100
# 1          Umba  66.6871   34.3429     42.64        81          56
# 2  Quatre Cocos -20.2078   57.7625     77.09        77          76
# 3       Mataura -46.1927  168.8643     42.30        85         100
# 4      Remedios  22.4947  -79.5458     70.72        89           2
#
#    Wind Speed Country Current Description
# 0       16.37      PF     overcast clouds
# 1        7.43      RU       broken clouds
# 2       11.63      MU       broken clouds
# 3        1.99      NZ     overcast clouds
# 4        2.19      CU           clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tautira      PF -17.7333 -149.1500     78.82        79         100
# 1          Umba      RU  66.6871   34.3429     42.64        81          56
# 2  Quatre Cocos      MU -20.2078   57.7625     77.09        77          76
# 3       Mataura      NZ -46.1927  168.8643     42.30        85         100
# 4      Remedios      CU  22.4947  -79.5458     70.72        89           2
#
#    Wind Speed Current Description
# 0       16.37     overcast clouds
# 1        7.43       broken clouds
# 2       11.63       broken clouds
# 3        1.99     overcast clouds
# 4        2.19           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
